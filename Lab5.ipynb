# %% [markdown]
# # Lab5

# %% [markdown]
# ## Extract sequences and create table

# %% [markdown]
# --------------
# ### Method 1

# %%
t = [["YES-1", "26-47", "N/A", "16-21, 49-54"],
     ["NOT-1", "44-66", "N/A", "40-43, 74-77"],
     ["AND-1", "30-45", "49-64", "16-23, 70-77"],
     ["OR-1", "27-46", "47-66","16-26, 67-77"]]

print ("| NAME   | OBS-1 start-end | OBS-2 start-end | Red start-end |")

for item in t:
    print ("|", item[0], " "*(5-len(item[0])), "|", 
           item[1], " "*(14-len(item[1])), "|", 
           item[2], " "*(14-len(item[2])), "|", item[3], " "*(8-len(item[3])), "|")
# Out:
# | NAME   | OBS-1 start-end | OBS-2 start-end | Red start-end |
# | YES-1  | 26-47           | N/A             | 16-21, 49-54  |
# | NOT-1  | 44-66           | N/A             | 40-43, 74-77  |
# | AND-1  | 30-45           | 49-64           | 16-23, 70-77  |
# | OR-1   | 27-46           | 47-66           | 16-26, 67-77  |

# %% [markdown]
# -------
# ### Method 2

# %%
riboswitch_1 = ["YES-1", "26-47", "not applicable", "16-21, 49-54" ]
riboswitch_2 = ["NOT-1", "44-66", "not applicable", "40-43, 74-77"]
riboswitch_3 = ["AND-1", "30-45", "49-64", "16-23, 70-77"]
riboswitch_4 = ["OR-1", "27-46", "47-66", "16-26, 67-77"]

students = [("Name", "OBS1 start/end", "  OBS2 start/end", "  Red regions start/end"), ("YES-1", "    26-47   ", "  not applicable    ", "  16-21, 49-54   " ), ("NOT-1", "    44-66   ", "   not applicable   ", "  40-43, 74-77   "), ("AND-1", "    30-45   ", "      49-64  ", "          16-23, 70-77"), ("OR-1", "    27-46   ", "      47-66   ", "          16-26, 67-77")]
for student in students:
    print(*student, sep='\t')  # python 3
#for student in students:
    #print ('\t'.join(str(i) for i in student))
# Out:
# Name	OBS1 start/end	  OBS2 start/end	  Red regions start/end
# YES-1	    26-47   	  not applicable    	  16-21, 49-54
# NOT-1	    44-66   	   not applicable   	  40-43, 74-77
# AND-1	    30-45   	      49-64  	          16-23, 70-77
# OR-1	    27-46   	      47-66   	          16-26, 67-77

# %% [markdown]
# ---------

# %%
import subprocess

# %%
seq_YES1 = "GGGCGACCCUGAUGAGCUUGAGUUUAGCUCGUCACUGUCCAGGUUCAAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCC"
seq_NOT1 = 'GGCAGGUACAUACAGCUGAUGAGUCCCAAAUAGGACGAAACGCGACACACACCACUAAACCGUGCAGUGUUUUGCGUCCUGUAUUCCACUGC'
seq_AND1 = 'GGGCGACCCUGAUGAGCUUGGUUUAGUAUUUACAGCUCCAUACAUGAGGUGUUAUCCCUAUGCAUGUUCGAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCCAGAGACAAU'
seq_OR1 = 'GGGCGACCCUGAUGAGCUUGGUUGAGUAUUUACAGCACCAUACAUGAGGUGUUCUCCCUACGCAAGUUCGAUCAGCGGAAACGGUGAAAGCCGUAGGUUGCCC'

# %%
p = subprocess.run(['RNAfold'], input=bytes(seq_YES1, 'ascii'), stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print(p.stderr.decode())
print (p.stdout.decode())
# Out:
# GGGCGACCCUGAUGAGCUUGAGUUUAGCUCGUCACUGUCCAGGUUCAAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCC
# ((((((((.(((((((((.......))))))))).((.((.(((...))).))))..(((((....))))).)))))))) (-33.00)

# %% [markdown]
# ### yes1 structure

# %%
from IPython.display import Image, display
display(Image(filename='yes1 structure.JPG', embed=True, width=300))

# %% [markdown]
# #### YES-1: Our structure has an extra stem loop compared to the one in the publication, which gives the overall structure a “cross-like” shape. The red regions have not bound each other, which ensures that the overall system will still returns the same results

# %%
p = subprocess.run(['RNAfold'], input=bytes(seq_NOT1, 'ascii'), stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print(p.stderr.decode())
print (p.stdout.decode())
# Out:
# GGCAGGUACAUACAGCUGAUGAGUCCCAAAUAGGACGAAACGCGACACACACCACUAAACCGUGCAGUGUUUUGCGUCCUGUAUUCCACUGC
# .((((....((((((.......((((......))))...((((((.((((..(((......)))..)))).)))))).))))))....)))) (-28.10)

# %% [markdown]
# -----------------------------------------------------------
# ### not1 structure

# %%
from IPython.display import Image, display
display(Image(filename='not1 structure.JPG', embed=True, width=300))

# %% [markdown]
# #### NOT-1: The overall structures are similar. The one we generated has a small extra-stem loop between the 15th and the 23rd nucleotide. The red regions are still bounded to each other in our structure.

# %%
p = subprocess.run(['RNAfold'], input=bytes(seq_AND1, 'ascii'), stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print(p.stderr.decode())
print (p.stdout.decode())
# Out:
# GGGCGACCCUGAUGAGCUUGGUUUAGUAUUUACAGCUCCAUACAUGAGGUGUUAUCCCUAUGCAUGUUCGAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCCAGAGACAAU
# (((((((((((((((((...((.(((.....(((.(((.......))).))).....))).))..)))).))))).....(((((....))))).))))))))......... (-38.40)

# %% [markdown]
# -----------------------------------------------------------
# ### and1 structure

# %%
from IPython.display import Image, display
display(Image(filename='and1 structure.JPG', embed=True, width=300))

# %% [markdown]
# #### AND-1: Our structure and the one in the publication are the same.

# %%
p = subprocess.run(['RNAfold'], input=bytes(seq_OR1, 'ascii'), stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print(p.stderr.decode())
print (p.stdout.decode())
# Out:
# GGGCGACCCUGAUGAGCUUGGUUGAGUAUUUACAGCACCAUACAUGAGGUGUUCUCCCUACGCAAGUUCGAUCAGCGGAAACGGUGAAAGCCGUAGGUUGCCC
# ((((((((((((((((((((((.(((.......((((((........)))))))))...)).))))))).))))).....(((((....))))).)))))))) (-40.90)

# %% [markdown]
# -----------------------------------------------------------
# ### or1 structure

# %%
from IPython.display import Image, display
display(Image(filename='or1 structure.JPG', embed=True, width=300))

# %% [markdown]
# #### OR-1: Our structure and the one in the publication are the same.

# %% [markdown]
# -----------------------------------------------------------
# ### OBS binding in YES-1

# %%
from IPython.display import Image, display
display(Image(filename='OBS binding in YES-1.JPG', embed=True, width=300))

# %% [markdown]
# #### OBS-YES1: It does look like the self-cleaving form of YES-1, we can observe the same stem loops structures. OBS binding induced the red regions to bind to each other, just like in the publication.

# %% [markdown]
# -----------------------------------------------------------
# ### OBS binding in NOT1

# %%
from IPython.display import Image, display
display(Image(filename='OBS binding in NOT1.JPG', embed=True, width=300))

# %% [markdown]
# #### OBS-NOT1: The structure we generated also looks like the self-cleaving form of NOT-1 seen in the publication. The binding of OBS induced the unbounding of the red regions, like in the paper.

# %% [markdown]
# -----------------------------------------------------------
# ### OBS1 in AND1

# %%
from IPython.display import Image, display
display(Image(filename='OBS1 in AND1.JPG', embed=True, width=300))

# %% [markdown]
# #### OBS1-AND1: We generated a very similar structure, where the red regions are not bound to each other so we would not get self-cleaving.

# %% [markdown]
# -----------------------------------------------------------
# ### OBS2 in AND1

# %%
from IPython.display import Image, display
display(Image(filename='OBS2 in AND1.JPG', embed=True, width=300))

# %% [markdown]
# #### OBS2-AND1: Even though the structure we generated differs from the one in the publication, the red regions are still unbound.

# %% [markdown]
# -----------------------------------------------------------
# ### OBS1 and OBS2 in AND1

# %%
from IPython.display import Image, display
display(Image(filename='OBS1 and OBS2 in AND1.JPG', embed=True, width=300))

# %% [markdown]
# #### OBS1 and OBS2- AND1: We get a very similar structure, the binding of both OBS induce the binding of the red regions and so cleaving.

# %% [markdown]
# ### So according to our result, the AND1 would work.

# %% [markdown]
# -----------------------------------------------------------
# ### OBS1 in OR1

# %%
from IPython.display import Image, display
display(Image(filename='OBS1 in OR1.JPG', embed=True, width=300))

# %% [markdown]
# #### OBS1-OR1: We generated a very different structure, according to our results the OBS1 binding caused the red regions to become unbound. Therefore, this structure would not self-cleave.

# %% [markdown]
# -----------------------------------------------------------
# ### OBS2 in OR1

# %%
from IPython.display import Image, display
display(Image(filename='OBS2 in OR1.JPG', embed=True, width=300))

# %% [markdown]
# #### OBS2-OR1: We generated very similar structures, OBS2 binding induced the red regions to bind to each other. So this structure would self-cleave.

# %% [markdown]
# -----------------------------------------------------------
# ### OBS1 and 2 in OR1

# %%
from IPython.display import Image, display
display(Image(filename='OBS1 and 2 in OR1.JPG', embed=True, width=300))

# %% [markdown]
# #### OBS1 and 2- OR1: We generated very similar structures, the binding of both OBS induced the red regions to bind to each other and therefore make the riboswitch self-cleave.
# ### Since, OBS1 does not induce self-cleaving, according to our results, the OR1 riboswitch will not work.

# %%
t = [["1", "1", "1"],
     ["1", "0", "0"],
     ["0", "1", "0"],
     ["0", "0", "0"]]

print ("| True | False | Output | ")

for item in t:
    print ("|", item[0], " "*(3-len(item[0])), "|", 
           item[1], " "*(4-len(item[1])), "|", 
           item[2], " "*(5-len(item[0])), "|")
# Out:
# | True | False | Output |
# | 1    | 1     | 1      |
# | 1    | 0     | 0      |
# | 0    | 1     | 0      |
# | 0    | 0     | 0      |

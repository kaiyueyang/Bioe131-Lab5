# %%
import subprocess

# %%
seq_YES1 = "GGGCGACCCUGAUGAGCUUGAGUUUAGCUCGUCACUGUCCAGGUUCAAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCC"
seq_NOT1 = 'GGCAGGUACAUACAGCUGAUGAGUCCCAAAUAGGACGAAACGCGACACACACCACUAAACCGUGCAGUGUUUUGCGUCCUGUAUUCCACUGC'
seq_AND1 = 'GGGCGACCCUGAUGAGCUUGGUUUAGUAUUUACAGCUCCAUACAUGAGGUGUUAUCCCUAUGCAUGUUCGAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCCAGAGACAAU'
seq_OR1 = 'GGGCGACCCUGAUGAGCUUGGUUGAGUAUUUACAGCACCAUACAUGAGGUGUUCUCCCUACGCAAGUUCGAUCAGCGGAAACGGUGAAAGCCGUAGGUUGCCC'

# %%
p = subprocess.run(['RNAfold'], input=bytes(seq_YES1, 'ascii'), stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print(p.stderr.decode())
print (p.stdout.decode())
# Out:
# GGGCGACCCUGAUGAGCUUGAGUUUAGCUCGUCACUGUCCAGGUUCAAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCC
# ((((((((.(((((((((.......))))))))).((.((.(((...))).))))..(((((....))))).)))))))) (-33.00)

# %% [markdown]
# yes1 structure
# ![Screenshot%20from%202018-09-26%2011-20-22.png](attachment:Screenshot%20from%202018-09-26%2011-20-22.png)

# %%
p = subprocess.run(['RNAfold'], input=bytes(seq_NOT1, 'ascii'), stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print(p.stderr.decode())
print (p.stdout.decode())
# Out:
# GGCAGGUACAUACAGCUGAUGAGUCCCAAAUAGGACGAAACGCGACACACACCACUAAACCGUGCAGUGUUUUGCGUCCUGUAUUCCACUGC
# .((((....((((((.......((((......))))...((((((.((((..(((......)))..)))).)))))).))))))....)))) (-28.10)

# %% [markdown]
# not1 structure
# ![Screenshot%20from%202018-09-26%2011-24-49.png](attachment:Screenshot%20from%202018-09-26%2011-24-49.png)

# %%
p = subprocess.run(['RNAfold'], input=bytes(seq_AND1, 'ascii'), stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print(p.stderr.decode())
print (p.stdout.decode())
# Out:
# GGGCGACCCUGAUGAGCUUGGUUUAGUAUUUACAGCUCCAUACAUGAGGUGUUAUCCCUAUGCAUGUUCGAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCCAGAGACAAU
# (((((((((((((((((...((.(((.....(((.(((.......))).))).....))).))..)))).))))).....(((((....))))).))))))))......... (-38.40)

# %% [markdown]
# and1 structure

# %%
from IPython.display import Image, display
display(Image(filename='and1 structure.JPG', embed=True))

# %%
p = subprocess.run(['RNAfold'], input=bytes(seq_OR1, 'ascii'), stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print(p.stderr.decode())
print (p.stdout.decode())
# Out:
# GGGCGACCCUGAUGAGCUUGGUUGAGUAUUUACAGCACCAUACAUGAGGUGUUCUCCCUACGCAAGUUCGAUCAGCGGAAACGGUGAAAGCCGUAGGUUGCCC
# ((((((((((((((((((((((.(((.......((((((........)))))))))...)).))))))).))))).....(((((....))))).)))))))) (-40.90)

# %% [markdown]
# or1 structure
# ![Screenshot%20from%202018-09-26%2011-32-45.png](attachment:Screenshot%20from%202018-09-26%2011-32-45.png)

# %% [markdown]
# OBS binding in YES-1
#
# ![Screenshot%20from%202018-09-26%2011-43-22.png](attachment:Screenshot%20from%202018-09-26%2011-43-22.png)

# %% [markdown]
# OBS binding in NOT1
# ![Screenshot%20from%202018-09-26%2011-46-27.png](attachment:Screenshot%20from%202018-09-26%2011-46-27.png)

# %% [markdown]
# OBS1 in AND1
# ![Screenshot%20from%202018-09-26%2011-51-42.png](attachment:Screenshot%20from%202018-09-26%2011-51-42.png)

# %% [markdown]
# OBS2 in AND1
# ![Screenshot%20from%202018-09-26%2011-53-47.png](attachment:Screenshot%20from%202018-09-26%2011-53-47.png)

# %% [markdown]
# OBS1 and OBS2 in AND1
# ![Screenshot%20from%202018-09-26%2011-54-50.png](attachment:Screenshot%20from%202018-09-26%2011-54-50.png)

# %% [markdown]
# OBS1 in OR1
# ![Screenshot%20from%202018-09-26%2011-55-48.png](attachment:Screenshot%20from%202018-09-26%2011-55-48.png)

# %% [markdown]
# OBS2 in OR1
# ![Screenshot%20from%202018-09-26%2011-56-44.png](attachment:Screenshot%20from%202018-09-26%2011-56-44.png)

# %% [markdown]
# OBS1 and 2 in OR1
# ![Screenshot%20from%202018-09-26%2011-57-49.png](attachment:Screenshot%20from%202018-09-26%2011-57-49.png)
